# %% [markdown]
# <a href="https://colab.research.google.com/github/ksj-ops/Assignment8/blob/main/20251177.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1
# 1. 체이닝(Chaining)
# -장점: 같은 자리에서 충돌이 일어난 원소들은 하나씩의 연결 리스트로 관리한다(계속 이어붙임)
# -단점: 연결 리스트를 위한 포인터 공간이 추가로 소요됩니다.또한 한 버킷에 데이터가 쏠리면 검색 성능이
# O(n)까지 나빠질 수 있습니다.
#
# 2. 개방 주소 방법(Open Addressing)
# -장점: 포인터 같은 추가적인 저장 공간이 필요 없어 메모리를 아낄 수 있습니다.
# -단점: 테이블이 꽉 차면 더 이상 저장할 수 없으므로, 공간을 늘리는 작업이 반드시 필요합니다.

# %% [markdown]
# #1
# 해시 함수의 결과값 범위는 0부터 1023까지이다. 하지만 테이블 크기가 1024로 설정되어있기때문에 메모리를 효율적으로 사용하지 못한다.

# %% [markdown]
# #2
# random함수를 사용한 점이 문제이다. 같은 입력 값 x에 대해 항상 동일한 결과값을 반환해야한다. 하지만 random 함수가 포함되면, 같은 x를 넣어도 실행할 때마다 결과가 달라져 데이터를 다시 찾을 수 없게 된다.

# %% [markdown]
# #4
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #5
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #6
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #7
# 일반적인 체이닝은 시간 복잡도가 O(1)이지만 새로운 키가 삽입될 때 리스트의 맨 뒤에 삽입된다면 시간 복잡도가
# O(n)이 될 것이다.

# %% [markdown]
# #8
# 삽입: 정렬된 상태를 유지하는 상태로 삽입해야하므로 O(n)의 시간이 걸린다.
#
# 삭제: 정렬 여부와 상관없이  O(n)의 시간이 걸리므로 여전히 동일한 시간복잡도를 가진다.
#
# 성공적인 검색:리스트에 원하는 데이터가 있다면, 해당 위치까지 도달해야하므로 O(n)의 시간이 걸린다.
#
# 실패하는 검색: 기존에는 데이터가 없음을 확실히 하기 위해 끝까지 해야하지만 정렬된 리스트에서는 중단될 수 있으므로 시간이 개선된다.
